# %% [markdown]
# # Stop Words
# Words like "a" and "the" appear so frequently that they don't require tagging as thoroughly as nouns, verbs and modifiers. We call these *stop words*, and they can be filtered from the text to be processed. spaCy holds a built-in list of some 305 English stop words.

# %%
# Perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Print the set of spaCy's default stop words (remember that sets are unordered):
print(nlp.Defaults.stop_words)
# Out:
# {'ca', 'just', 'itself', 'own', 'an', 'n’t', 'together', '‘d', 'which', 'have', 'where', 'may', 'herein', '’d', 'myself', 'anyhow', 'thru', 'must', "'m", '’s', 'sometime', 'my', 'almost', 'whether', 'someone', 're', 'hereby', 'himself', 'whereas', 'much', 'what', 'to', 'become', '‘ve', 'us', 'top', 'less', 'had', 'ours', 'via', 'made', 'seeming', 'below', 'third', "n't", 'various', 'towards', 'everyone', 'four', 'with', 'front', 'therefore', 'am', 'else', 'beforehand', 'beside', 'i', 'as', 'twelve', '’ve', 'both', 'will', 'this', 'due', '’ll', 'becoming', 'does', 'hers', 'anyway', 'it', 'if', 'any', 'hereupon', 'sometimes', 'out', 'neither', 'everywhere', 'except', 'your', '‘m', "'re", 'hence', 'many', 'becomes', 'others', 'because', 'can', 'thereafter', 'back', 'whom', 'amount', 'off', 'serious', 'however', 'whereupon', 'anyone', 'until', 'whence', 'a', 'first', 'two', 'something', "'ve", 'seem', 'side', 'me', 'nevertheless', 'while', 'about', 'latter', 'mostly', 'move', 'yours', "'d", 'ever', 'latterly', 'should', 'nor', 'these', 'through', 'you', "'s", 'afterwards', 'anywhere', 'his', 'whoever', 'than', 'since', 'seems', 'further', 'her', 'here', 'anything', 'call', 'herself', 'using', 'some', 'into', 'even', 'who', 'cannot', 'from', 'no', 'whereafter', 'up', 'name', 'go', 'n‘t', 'get', 'put', 'under', 'whatever', 'so', 'that', 'wherever', 'by', 'each', 'themselves', 'not', 'being', 'those', 'too', 'somewhere', 'before', 'were', 'nine', 'every', 'either', 'full', 'fifteen', 'six', 'been', 'how', 'nowhere', 'amongst', 'might', 'we', 'their', 'alone', 'doing', 'did', 'still', 'or', 'again', 'around', '‘ll', 'see', 'after', 'fifty', 'one', 'please', 'therein', 'are', 'part', 'became', 'always', 'former', 'more', 'its', 'least', 'and', 'at', 'few', 'moreover', 'empty', 'over', 'although', 'rather', 'hundred', 'never', 'within', 'everything', 'next', 'once', 'whither', 'without', 'the', 'show', 'noone', 'was', 'yet', 'thereby', 'whole', '’m', 'he', 'of', 'say', 'namely', 'quite', 'unless', 'but', 'she', 'enough', 'could', 'per', 'beyond', 'indeed', 'hereafter', 'ten', 'three', 'along', 'in', 'nobody', 'for', 'besides', 'why', '‘re', 'down', 'really', 'whose', 'our', 'there', '’re', 'toward', 'somehow', 'five', 'well', 'among', 'thereupon', 'perhaps', 'seemed', 'when', 'take', 'eleven', 'used', 'most', 'same', 'thence', 'all', 'sixty', 'twenty', 'is', 'between', 'yourselves', 'last', 'forty', 'also', 'behind', 'other', 'make', 'ourselves', 'otherwise', 'eight', 'would', 'though', 'nothing', 'meanwhile', 'throughout', 'very', 'several', 'against', 'onto', 'regarding', 'during', 'elsewhere', 'yourself', 'above', 'across', 'him', 'thus', 'be', 'whenever', "'ll", 'them', 'has', 'do', 'give', 'now', 'wherein', 'bottom', 'such', '‘s', 'only', 'already', 'often', 'keep', 'whereby', 'then', 'done', 'upon', 'another', 'formerly', 'none', 'mine', 'they', 'on'}

# %%
print(len(nlp.Defaults.stop_words))
# Out:
# 326

# %% [markdown]
# ## To see if a word is a stop word

# %%
nlp.vocab['gaming'].is_stop
# Out:
# False

# %%
nlp.vocab['the'].is_stop
# Out:
# True

# %% [markdown]
# ## Adding a Custom Stop Word
# There may be times when you wish to add a stop word to the default set. Perhaps you decide that `'btw'` (common shorthand for "by the way") should be considered a stop word.

# %%
# Add the word to the set of stop words. Use lowercase!
nlp.Defaults.stop_words.add('btw')

# Set the stop_word tag on the lexeme
nlp.vocab['btw'].is_stop = True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %% [markdown]
# <font color=lightgreen>When adding stop words, always use lowercase. Lexemes are converted to lowercase before being added to **vocab**.</font>

# %% [markdown]
# ## Removing a word from the stop words list
# Alternatively, you may decide that `'beyond'` should not be considered a stop word.

# %%
# Remove the word from the set of stop words
nlp.Defaults.stop_words.remove('beyond')

# Remove the stop_word tag from the lexeme
nlp.vocab['beyond'].is_stop = False

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['beyond'].is_stop
# Out:
# False
