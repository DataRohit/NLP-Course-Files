# %% [markdown]
# # Tokenization

# %%
# Import spaCy and load the language library
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# Create a string that includes opening and closing quotation marks
mystring = '"We\'re moving to L.A.!"'
print(mystring)
# Out:
# "We're moving to L.A.!"

# %%
# Create a Doc object and explore tokens
doc = nlp(mystring)

for token in doc:
  print(token.text, end=' | ')
# Out:
# " | We | 're | moving | to | L.A. | ! | " |

# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*Sibm12vBIZTjTDBp3I7yeQ.png" width=600/>
#
# -  **Prefix**:	Character(s) at the beginning &#9656; `$ ( “ ¿`
# -  **Suffix**:	Character(s) at the end &#9656; `km ) , . ! ”`
# -  **Infix**:	Character(s) in between &#9656; `- -- / ...`
# -  **Exception**: Special-case rule to split a string into several tokens or prevent a token from being split when punctuation rules are applied &#9656; `St. U.S.`

# %% [markdown]
# ## Prefixes, Suffixes and Infixes

# %%
doc2 = nlp(u"We're here to help! Send snail-mail, email support@oursite.com or visit us at http://www.oursite.com!")

for t in doc2:
  print(t)
# Out:
# We
# 're
# here
# to
# help
# !
# Send
# snail
# -
# mail
# ,
# email
# support@oursite.com
# or
# visit
# us
# at
# http://www.oursite.com
# !

# %% [markdown]
# <font color=lightgreen>Note that the exclamation points, comma, and the hyphen in 'snail-mail' are assigned their own tokens, yet both the email address and website are preserved.</font>

# %%
doc3 = nlp(u'A 5km NYC cab ride costs $10.30')

for t in doc3:
  print(t)
# Out:
# A
# 5
# km
# NYC
# cab
# ride
# costs
# $
# 10.30

# %% [markdown]
# <font color=lightgreen>Here the distance unit and dollar sign are assigned their own tokens, yet the dollar amount is preserved.</font>

# %% [markdown]
# ## Exceptions

# %%
doc4 = nlp(u"Let's visit St. Louis in the U.S. next year.")

for t in doc4:
  print(t)
# Out:
# Let
# 's
# visit
# St.
# Louis
# in
# the
# U.S.
# next
# year
# .

# %% [markdown]
# <font color=lightgreen>Here the abbreviations for "Saint" and "United States" are both preserved.</font>

# %% [markdown]
# ## Counting Tokens
# `Doc` objects have a set number of tokens:

# %%
len(doc)
# Out:
# 8

# %% [markdown]
# ## Counting Vocab Entries
# `Vocab` objects contain a full library of items!

# %%
len(doc.vocab)
# Out:
# 512

# %% [markdown]
# <font color=lightgreen>NOTE: This number changes based on the language library loaded at the start, and any new lexemes introduced to the `vocab` when the `Doc` was created.</font>

# %% [markdown]
# ## Tokens can be retrieved by index position and slice
# `Doc` objects can be thought of as lists of `token` objects. As such, individual tokens can be retrieved by index position, and spans of tokens can be retrieved through slicing:

# %%
doc5 = nlp(u'It is better to give than to receive.')

# Retrieve the third token:
doc5[2]
# Out:
# better

# %%
# Retrieve three tokens from the middle:
doc5[2:5]
# Out:
# better to give

# %%
# Retrieve the last four tokens:
doc5[-4:]
# Out:
# than to receive.

# %% [markdown]
# ## Tokens cannot be reassigned
# Although `Doc` objects can be considered lists of tokens, they do *not* support item reassignment:

# %%
doc6 = nlp(u'My dinner was horrible.')
doc7 = nlp(u'Your dinner was delicious.')

# Try to change "My dinner was horrible" to "My dinner was delicious"
doc6[3] = doc7[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-e5465104e994> in <module>()
#       3
#       4 # Try to change "My dinner was horrible" to "My dinner was delicious"
# ----> 5 doc6[3] = doc7[3]
#
# TypeError: 'spacy.tokens.doc.Doc' object does not support item assignment

# %% [markdown]
# # Named Entities

# %%
doc8 = nlp(u'Apple to build a Hong Kong factory for $6 million')

for token in doc8:
  print(token.text, end=' | ')

print('\n----')

for ent in doc8.ents:
  print(f"{ent.text} - {ent.label_} - {str(spacy.explain(ent.label_))}")
# Out:
# Apple | to | build | a | Hong | Kong | factory | for | $ | 6 | million |
# ----
# Apple - ORG - Companies, agencies, institutions, etc.
# Hong Kong - GPE - Countries, cities, states
# $6 million - MONEY - Monetary values, including unit

# %% [markdown]
# <font color=lightgreen>Note how two tokens combine to form the entity `Hong Kong`, and three tokens combine to form the monetary entity:  `$6 million`</font>

# %%
# Counting the Number of Named Entities
len(doc8.ents)
# Out:
# 3

# %% [markdown]
# # Noun Chunks

# %%
doc9 = nlp(u"Autonomous cars shift insurance liability toward manufacturers.")

for chunk in doc9.noun_chunks:
  print(chunk.text)
# Out:
# Autonomous cars
# insurance liability
# manufacturers

# %%
doc10 = nlp(u"Red cars do not carry higher insurance rates.")

for chunk in doc10.noun_chunks:
  print(chunk.text)
# Out:
# Red cars
# higher insurance rates

# %%
doc11 = nlp(u"He was a one-eyed, one-horned, flying, purple people-eater.")

for chunk in doc11.noun_chunks:
  print(chunk.text)
# Out:
# He
# a one-eyed, one-horned, flying, purple people-eater

# %% [markdown]
# # Built-in Visualizers

# %% [markdown]
# ## Visualizing the dependency parse

# %%
from spacy import displacy

doc = nlp(u'Apple is going to build a U.K. factory for $6 million.')
displacy.render(doc, style='dep', jupyter=True, options={'distance': 110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2ffedd97d82b41cb845e103c8be646fc-0" class="displacy" width="1370" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">going</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">build</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">U.K.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">factory</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">million.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2ffedd97d82b41cb845e103c8be646fc-0-0" stroke-width="2px" d="M70,222.0 C70,112.0 260.0,112.0 260.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2ffedd97d82b41cb845e103c8be646fc-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,224.0 L62,212.0 78,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2ffedd97d82b41cb845e103c8be646fc-0-1" stroke-width="2px" d="M180,222.0 C180,167.0 255.0,167.0 255.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2ffedd97d82b41cb845e103c8be646fc-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,224.0 L172,212.0 188,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2ffedd97d82b41cb845e103c8be646fc-0-2" stroke-width="2px" d="M400,222.0 C400,167.0 475.0,167.0 475.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2ffedd97d82b41cb845e103c8be646fc-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,224.0 L392,212.0 408,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2ffedd97d82b41cb845e103c8be646fc-0-3" stroke-width="2px" d="M290,222.0 C290,112.0 480.0,112.0 480.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2ffedd97d82b41cb845e103c8be646fc-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M480.0,224.0 L488.0,212.0 472.0,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2ffedd97d82b41cb845e103c8be646fc-0-4" stroke-width="2px" d="M620,222.0 C620,112.0 810.0,112.0 810.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2ffedd97d82b41cb845e103c8be646fc-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M620,224.0 L612,212.0 628,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2ffedd97d82b41cb845e103c8be646fc-0-5" stroke-width="2px" d="M730,222.0 C730,167.0 805.0,167.0 805.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2ffedd97d82b41cb845e103c8be646fc-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M730,224.0 L722,212.0 738,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2ffedd97d82b41cb845e103c8be646fc-0-6" stroke-width="2px" d="M510,222.0 C510,57.0 815.0,57.0 815.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2ffedd97d82b41cb845e103c8be646fc-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M815.0,224.0 L823.0,212.0 807.0,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2ffedd97d82b41cb845e103c8be646fc-0-7" stroke-width="2px" d="M510,222.0 C510,2.0 930.0,2.0 930.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2ffedd97d82b41cb845e103c8be646fc-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M930.0,224.0 L938.0,212.0 922.0,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2ffedd97

# %% [markdown]
# ## Visualizing the entity recognizer

# %%
doc = nlp(u'Over the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million.')
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPods
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for a profit of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .</div></span>

# %% [markdown]
# ## Creating Visualizations Outside of Jupyter

# %%
doc = nlp(u'This is a sentence.')
displacy.serve(doc, style='dep')
# Out:
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.
